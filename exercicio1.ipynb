# %% [markdown]
# <a href="https://colab.research.google.com/github/guisouza565656-commits/Liberalismo-/blob/main/exercicio1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. faça um algoritimo para ler dois numeros

# %% [markdown]
#  ### algoritimo da soma
#
# 1.leia o primero número e guarde numa variável chamda numero1
#
# 2.leia o segundo numero e guarde em outra variável chamada numero2
#
# 3.faça a soma das duas variáveis e guarde o resultado chamda soma
#
# 4.mostre o resultado

# %% [markdown]
# ###algoritimo da media
# 2 faça um algoritimo para ler tres numeros e imprimir a soma, media e produtos dos numeros lidos.
#
# 1.leia o primeiro numero e salve na variavel num1
#
# 2.leia o segudo numero e salve na variavel num2
#
# 3.leia o terceiro numero e salve na variavel num3
#
# 4.some os 3 numero e salve na variavel soma
#
# 5.mostre o resultado da soma

# %%
num1 = int(input("digite o primeiro numero:"))
num2 = int(input("digite o segundo numero:"))
num3 = int(input("digite o terceiro numero:"))
soma = num1 + num2 + num3
print(f"a soma dos numeros é {soma}")
# Out:
# digite o primeiro numero:32
# digite o segundo numero:3
# digite o terceiro numero:23
# a soma dos numeros é 58

# %% [markdown]
# ### algoritimo do maior e menor
#
# 1. leia o primeiro numero e salve na variavel num1
# 2.leia o segundo numero e salve na variavel num2
# 3.descobrir o maior
# 4.mostrae o menor
# 5.descobrir o menor
# 6.mostrar o menor
# 7.descobrir se são iguais
# 8.mostrar se são iguais

# %%
num1 = int(input("digite o primeiro numero:"))
num2 = int(input("digite o segundo numero:"))
if num1 > num2:
    print(f"o maior numero é {num1}")
    print(f"o menor numero é {num2}")
elif num2 > num1:
    print(f"o maior numero é {num2}")
    print(f"o menor numero é {num1}")
else:
    print("os numeros são iguais")
# Out:
# digite o primeiro numero:56
# digite o segundo numero:34
# o maior numero é 56
# o menor numero é 34
